# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from itertools import product

import xgboost as xgb

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, make_scorer
from sklearn.model_selection import KFold

# %%
print(f"XGBoost version: {xgb.__version__}")
# Out:
# XGBoost version: 2.1.4

# %%
df = pd.read_csv('Food_Time_Data_Set.csv')
df.head()
# Out:
#      ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  4607     INDORES13DEL02                 37.0                      4.9
# 1  B379     BANGRES18DEL02                 34.0                      4.5
# 2  5D6D     BANGRES19DEL01                 23.0                      4.4
# 3  7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4  70A2     CHENRES12DEL01                 32.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Type_of_order Type_of_vehicle  temperature  \
# 0                    75.912471        Snack      motorcycle         17.11
# 1                    77.813237        Snack         scooter         19.50
# 2                    77.688400       Drinks      motorcycle         20.45
# 3                    77.026494       Buffet      motorcycle         23.86
# 4                    80.289982        Snack         scooter         26.55
#
#    humidity  precipitation weather_description  Unnamed: 14 Traffic_Level  \
# 0      77.0            0.0                haze          NaN           Low
# 1      93.0            0.0                mist          NaN     Very High
# 2      91.0            0.0                mist          NaN           Low
# 3      78.0            0.0                mist          NaN      Moderate
# 4      87.0            0.0                mist          NaN          High
#
#    Distance (km)       TARGET
# 0            NaN  21.66666667
# 1          37.17  85.26666667
# 2           3.34  28.58333333
# 3          10.05  35.18333333
# 4           9.89        43.45

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           10000 non-null  object
#  1   Delivery_person_ID           10000 non-null  object
#  2   Delivery_person_Age          10000 non-null  float64
#  3   Delivery_person_Ratings      10000 non-null  float64
#  4   Restaurant_latitude          10000 non-null  float64
#  5   Restaurant_longitude         10000 non-null  float64
#  6   Delivery_location_latitude   10000 non-null  float64
#  7   Delivery_location_longitude  10000 non-null  float64
#  8   Type_of_order                10000 non-null  object
#  9   Type_of_vehicle              10000 non-null  object
#  10  temperature                  9995 non-null   float64
#  11  humidity                     9995 non-null   float64
#  12  precipitation                9995 non-null   float64
#  13  weather_description          9995 non-null   object
#  14  Unnamed: 14                  0 non-null      float64
#  15  Traffic_Level                9085 non-null   object
#  16  Distance (km)                9080 non-null   float64
#  17  TARGET                       9459 non-null   object
# dtypes: float64(11), object(7)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Step 0: Descriptive Statistics

# %% [markdown]
# Section for Corbett and Tanner

# %% [markdown]
# Descriptive Analysis (From Prof Instructions)
# - Number of columns and rows
# - Percent of missing values by columns
# - Means, medians, modes, correlations, variance, outliers
# - Data visualizations such as scatter plots or correlation plots

# %%
# drop the unnamed column with 0 records from df
df.drop('Unnamed: 14', axis=1, inplace=True)

# Number of columns and rows
# df.shape returns a tuple (rows, columns)
# format output with f-string

print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")

# %%
# Percent of missing values by columns
# Calculate percentage of missing values for each column
# look into .isnull() and .sum() and divide by len of df
# Sort values in descending order for each column and format output
# Display results with column names and missing percentages

missing_values = df.isnull().sum() / len(df)
missing_values = missing_values[missing_values > 0]
missing_values.sort_values(ascending=False, inplace=True)
missing_values = pd.DataFrame(missing_values, columns=['Missing Values'])
missing_values
# Out:
#                              Missing Values
# Traffic_Level                      0.091591
# TARGET                             0.054195
# weather_description                0.000600
# precipitation                      0.000600
# humidity                           0.000600
# temperature                        0.000600
# Type_of_vehicle                    0.000100
# Type_of_order                      0.000100
# Delivery_location_longitude        0.000100
# Delivery_location_latitude         0.000100
# Restaurant_longitude               0.000100
# Restaurant_latitude                0.000100
# Delivery_person_Ratings            0.000100
# Delivery_person_Age                0.000100

# %%
# Calculate descriptive statistics for numeric columns
numeric_descriptive_stats = df.describe()
print(numeric_descriptive_stats)
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         10000.000000             10000.000000         10000.000000
# mean             29.522000                 4.629370            16.893418
# std               5.700348                 0.322941             8.330948
# min              15.000000                 1.000000           -30.902872
# 25%              25.000000                 4.500000            12.913041
# 50%              29.000000                 4.700000            18.546258
# 75%              34.000000                 4.800000            22.727021
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          10000.000000                10000.000000
# mean              70.177749                   17.412655
# std               23.203352                    7.336846
# min              -88.352885                    0.010000
# 25%               73.170937                   12.983959
# 50%               75.902847                   18.626216
# 75%               78.047717                   22.785089
# max               88.433452                   31.054057
#
#        Delivery_location_longitude  temperature     humidity  precipitation  \
# count                 10000.000000  9995.000000  9995.000000    9995.000000
# mean                     70.880072    22.936907    66.164882       0.016233
# std                      21.174585     3.379448    15.602939       0.074911
# min                       0.010000     6.770000    27.000000       0.000000
# 25%                      73.753278    20.140000    54.000000       0.000000
# 50%                      76.022574    23.000000    67.000000       0.000000
# 75%                      78.128092    25.980000    81.000000       0.000000
# max                      88.563452    29.050000    94.000000       1.460000
#
#        Distance (km)
# count    9080.000000
# mean       14.292747
# std         8.376254
# min         1.550000
# 25%         7.620000
# 50%        13.400000
# 75%        19.610000
# max        59.840000

# %%
# Calculate mode for all columns (including categorical)
# look into .mode() and output/print results
mode_values = df.mode()
print(mode_values)
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  5.00E+09     CHENRES01DEL02                 29.0                      4.6
# 1  6.00E+02    COIMBRES06DEL01                  NaN                      NaN
# 2  6.00E+03   RANCHIRES18DEL01                  NaN                      NaN
# 3  9.00E+02      SURRES16DEL01                  NaN                      NaN
# 4  BEF 1.00                NaN                  NaN                      NaN
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                  0.0                   0.0                        0.04
# 1                  NaN                   NaN                         NaN
# 2                  NaN                   NaN                         NaN
# 3                  NaN                   NaN                         NaN
# 4                  NaN                   NaN                         NaN
#
#    Delivery_location_longitude Type_of_order Type_of_vehicle  temperature  \
# 0                         0.04        Snack      motorcycle         26.28
# 1                          NaN           NaN             NaN          NaN
# 2                          NaN           NaN             NaN          NaN
# 3                          NaN           NaN             NaN          NaN
# 4                          NaN           NaN             NaN          NaN
#
#    humidity  precipitation weather_description Traffic_Level  Distance (km)  \
# 0      73.0            0.0           clear sky          High           2.41
# 1       NaN            NaN                 NaN           NaN            NaN
# 2       NaN            NaN                 NaN           NaN            NaN
# 3       NaN            NaN                 NaN           NaN            NaN
# 4       NaN            NaN                 NaN           NaN            NaN
#
#     TARGET
# 0  #VALUE!
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
# Calculate correlation matrix for numeric columns
# look into .corr() and make sure you only apply it to columns with int and/or float data types
# output/print results
numeric_columns = df.select_dtypes(include=['int64', 'float64'])
correlation_matrix = numeric_columns.corr()
print(correlation_matrix)
# Out:
#                              Delivery_person_Age  Delivery_person_Ratings  \
# Delivery_person_Age                     1.000000                -0.079998
# Delivery_person_Ratings                -0.079998                 1.000000
# Restaurant_latitude                     0.003199                -0.029883
# Restaurant_longitude                   -0.010028                -0.037778
# Delivery_location_latitude              0.013251                -0.023599
# Delivery_location_longitude             0.002668                -0.025024
# temperature                             0.000605                 0.000772
# humidity                                0.000067                 0.022189
# precipitation                           0.002341                 0.030803
# Distance (km)                           0.004403                -0.116631
#
#                              Restaurant_latitude  Restaurant_longitude  \
# Delivery_person_Age                     0.003199             -0.010028
# Delivery_person_Ratings                -0.029883             -0.037778
# Restaurant_latitude                     1.000000              0.660486
# Restaurant_longitude                    0.660486              1.000000
# Delivery_location_latitude              0.842277              0.616935
# Delivery_location_longitude             0.587935              0.903097
# temperature                            -0.347084             -0.274918
# humidity                               -0.515785             -0.228425
# precipitation                          -0.409904             -0.580219
# Distance (km)                           0.044383             -0.016893
#
#                              Delivery_location_latitude  \
# Delivery_person_Age                            0.013251
# Delivery_person_Ratings                       -0.023599
# Restaurant_latitude                            0.842277
# Restaurant_longitude                           0.616935
# Delivery_location_latitude                     1.000000
# Delivery_location_longitude                    0.689674
# temperature                                   -0.408238
# humidity                                      -0.603954
# precipitation                                 -0.477870
# Distance (km)                                  0.050637
#
#                              Delivery_location_longitude  temperature  \
# Delivery_person_Age                             0.002668     0.000605
# Delivery_person_Ratings                        -0.025024     0.000772
# Restaurant_latitude                             0.587935    -0.347084
# Restaurant_longitude                            0.903097    -0.274918
# Delivery_location_latitude                      0.689674    -0.408238
# Delivery_location_longitude                     1.000000    -0.308566
# temperature                                    -0.308566     1.000000
# humidity                                       -0.254383    -0.052383
# precipitation                                  -0.642457     0.219732
# Distance (km)                                  -0.007216    -0.032433
#
#                              humidity  precipitation  Distance (km)
# Delivery_person_Age          0.000067       0.002341       0.004403
# Delivery_person_Ratings      0.022189       0.030803      -0.116631
# Restaurant_latitude         -0.515785      -0.409904       0.044383
# Restaurant_longitude        -0.228425      -0.580219      -0.016893
# Delivery_location_latitude  -0.603954      -0.477870       0.050637
# Delivery_location_longitude -0.254383      -0.642457      -0.007216
# temperature                 -0.052383       0.219732      -0.032433
# humidity                     1.000000       0.226596      -0.121800
# precipitation                0.226596       1.000000       0.019006
# Distance (km)               -0.121800       0.019006       1.000000

# %%
# Calculate variance for numeric columns
# look into .var() and make sure you only apply it to columns with int and/or float data types
variance_values = numeric_columns.var()
print(variance_values)
# Out:
# Delivery_person_Age             32.493965
# Delivery_person_Ratings          0.104291
# Restaurant_latitude             69.404689
# Restaurant_longitude           538.395537
# Delivery_location_latitude      53.829303
# Delivery_location_longitude    448.363071
# temperature                     11.420667
# humidity                       243.451698
# precipitation                    0.005612
# Distance (km)                   70.161627
# dtype: float64

# %%
# Detect outliers using IQR method for numeric columns
# define a function detect outliers
# where Q1 is quantile 0.25 and Q3 is quantile 0.75
# interquantile IQR = Q3 - Q1
# calculate lower_bound as Q1 - 1.5 x IQR
# calculate upper_bount as Q3 + 1.5 x IQR
# apply df filters to select values below lower_bound or above upper_bound

def detect_outliers(df, column):
    
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

# make loop to go over numeric columns and then call detect outliers function
# print the number of outliers for each column and the sample of outliers .head()

for column in numeric_columns.columns:
    outliers = detect_outliers(df, column)
    print(f"Number of outliers in {column}: {len(outliers)}")
    print(outliers.head())
# Out:
# Number of outliers in Delivery_person_Age: 10
#             ID Delivery_person_ID  Delivery_person_Age  \
# 3586       46D     BANGRES05DEL01                 50.0
# 4714       493      HYDRES17DEL01                 50.0
# 5169       4F2      JAPRES08DEL01                 50.0
# 5362       430     BANGRES19DEL01                 50.0
# 5651  BEF 1.00      AGRRES13DEL02                 50.0
#
#       Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 3586                      6.0           -12.970324            -77.645748
# 4714                      6.0           -17.451976            -78.385883
# 5169                      6.0           -26.910262            -75.783013
# 5362                      6.0            12.914264             77.678400
# 5651                      6.0           -27.159795            -78.042990
#
#       Delivery_location_latitude  Delivery_location_longitude Type_of_order  \
# 3586                   13.010324                    77.685748         Meal
# 4714                   17.561976                    78.495883        Snack
# 5169                   27.020262                    75.893013       Drinks
# 5362                   13.024264                    77.788400         Meal
# 5651                   27.209795                    78.092990       Drinks
#
#         Type_of_vehicle  temperature  humidity  precipitation  \
# 3586  electric_scooter         19.55      93.0            0.0
# 4714           bicycle         21.05      65.0            0.0
# 5169           scooter         23.90      28.0            0.0
# 5362  electric_scooter         22.86      74.0            0.0
# 5651           scooter         25.96      37.0            0.0
#
#      weather_description Traffic_Level  Distance (km)   TARGET
# 3586                mist           NaN            NaN  #VALUE!
# 4714       broken clouds           NaN            NaN  #VALUE!
# 5169           clear sky           NaN            NaN  #VALUE!
# 5362                haze     Very High          27.03     55.8
# 5651           clear sky           NaN            NaN  #VALUE!
# Number of outliers in Delivery_person_Ratings: 548
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 15   3AAB      MYSRES01DEL01                 35.0                      4.0
# 23   539B      MUMRES02DEL01                 25.0                      4.0
# 27   2288     BANGRES09DEL03                 32.0                      4.0
# 33   2876   RANCHIRES02DEL01                 32.0                      3.5
# 113  3F01      MUMRES15DEL01                 39.0                      3.8
#
#      Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 15             12.311072             76.654878                   12.351072
# 23             19.221315             72.862381                   19.261315
# 27             12.934179             77.615797                   13.024179
# 33              0.000000              0.000000                    0.110000
# 113            19.176269             72.836721                   19.286269
#
#      Delivery_location_longitude Type_of_order Type_of_vehicle  temperature  \
# 15                     76.694878         Meal         scooter         17.97
# 23                     72.902381       Buffet      motorcycle         24.51
# 27                     77.705797       Buffet      motorcycle         19.89
# 33                      0.110000        Snack         scooter         26.27
# 113                    72.946721       Drinks      motorcycle         27.04
#
#      humidity  precipitation weather_description Traffic_Level  Distance (km)  \
# 15       77.0            0.0    scattered clouds      Moderate          10.51
# 23       47.0            0.0           clear sky          High           8.97
# 27       93.0            0.0                mist     Very High          17.37
# 33       84.0            0.0     overcast clouds           NaN            NaN
# 113      48.0            0.0           clear sky     Very High          25.68
#
#           TARGET
# 15         29.45
# 23   34.61666667
# 27   57.93333333
# 33       #VALUE!
# 113  70.41666667
# Number of outliers in Restaurant_latitude: 110
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 92   C042     AGRRES010DEL01                 34.0                      4.7
# 283  C044      AGRRES12DEL03                 32.0                      4.7
# 289   4DB     PUNERES02DEL03                 29.0                      4.6
# 425  C003      DEHRES13DEL02                 29.0                      4.6
# 534   473      MYSRES07DEL03                 29.0                      4.6
#
#      Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 92            -27.163303             78.057044                   27.233303
# 283           -27.165108             78.015053                   27.225108
# 289           -18.551440            -73.804855                   18.611440
# 425           -30.366322            -78.070453                   30.496322
# 534           -12.325461            -76.632278                   12.385461
#
#      Delivery_location_longitude Type_of_order Type_of_vehicle  temperature  \
# 92                     78.127044       Drinks         scooter         21.55
# 283                    78.075053         Meal         scooter         21.71
# 289                    73.864855         Meal         scooter         19.12
# 425                    78.200453        Snack         scooter         10.63
# 534                    76.692278       Buffet         scooter         18.30
#
#      humidity  precipitation weather_description Traffic_Level  Distance (km)  \
# 92       52.0            0.0           clear sky           NaN            NaN
# 283      51.0            0.0           clear sky           NaN            NaN
# 289      65.0            0.0           clear sky           NaN            NaN
# 425      80.0            0.0           clear sky           NaN            NaN
# 534      77.0            0.0    scattered clouds           NaN            NaN
#
#       TARGET
# 92   #VALUE!
# 283  #VALUE!
# 289  #VALUE!
# 425  #VALUE!
# 534  #VALUE!
# Number of outliers in Restaurant_longitude: 1056
#       ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 18  C9CF      KOLRES15DEL03                 21.0                      4.7
# 33  2876   RANCHIRES02DEL01                 32.0                      3.5
# 45  C644      KOLRES16DEL02                 37.0                      4.9
# 52  C1FF     AURGRES20DEL03                 25.0                      5.0
# 57  8E6C      VADRES02DEL02                 39.0                      4.2
#
#     Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 18            22.552672             88.352885                   22.582672
# 33             0.000000              0.000000                    0.110000
# 45            22.539129             88.365507                   22.559129
# 52             0.000000              0.000000                    0.030000
# 57             0.000000              0.000000                    0.080000
#
#     Delivery_location_longitude Type_of_order Type_of_vehicle  temperature  \
# 18                    88.382885         Meal      motorcycle         22.99
# 33                     0.110000        Snack         scooter         26.27
# 45                    88.385507        Snack         scooter         22.99
# 52                     0.030000        Snack      motorcycle         26.28
# 57                     0.080000        Snack         scooter         26.25
#
#     humidity  precipitation weather_description Traffic_Level  Distance (km)  \
# 18      83.0            0.0                haze      Moderate           8.07
# 33      84.0            0.0     overcast clouds           NaN            NaN
# 45      83.0            0.0                haze           Low           5.32
# 52      85.0            0.1          light rain           NaN            NaN
# 57      85.0            0.0     overcast clouds           NaN            NaN
#
#          TARGET
# 18  31.73333333
# 33      #VALUE!
# 45  24.86666667
# 52          NaN
# 57      #VALUE!
# Number of outliers in Delivery_location_latitude: 0
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Type_of_order, Type_of_vehicle, temperature, humidity, precipitation, weather_description, Traffic_Level, Distance (km), TARGET]
# Index: []
# Number of outliers in Delivery_location_longitude: 1545
#       ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 6   95B4   RANCHIRES15DEL01                 33.0                      4.7
# 18  C9CF      KOLRES15DEL03                 21.0                      4.7
# 20  5795   RANCHIRES06DEL02                 31.0                      4.7
# 33  2876   RANCHIRES02DEL01                 32.0                      3.5
# 45  C644      KOLRES16DEL02                 37.0                      4.9
#
#     Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 6             23.369746             85.339820                   23.479746
# 18            22.552672             88.352885                   22.582672
# 20            23.357804             85.325146                   23.487804
# 33             0.000000              0.000000                    0.110000
# 45            22.539129             88.365507                   22.559129
#
#     Delivery_location_longitude Type_of_order    Type_of_vehicle  temperature  \
# 6                     85.449820         Meal            scooter         17.51
# 18                    88.382885         Meal         motorcycle         22.99
# 20                    85.455146         Meal   electric_scooter         17.85
# 33                     0.110000        Snack            scooter         26.27
# 45                    88.385507        Snack            scooter         22.99
#
#     humidity  precipitation weather_description Traffic_Level  Distance (km)  \
# 6       69.0            0.0           clear sky          High          19.11
# 18      83.0            0.0                haze      Moderate           8.07
# 20      67.0            0.0           clear sky     Very High          22.26
# 33      84.0            0.0     overcast clouds           NaN            NaN
# 45      83.0            0.0                haze           Low           5.32
#
#          TARGET
# 6   38.16666667
# 18  31.73333333
# 20  49.26666667
# 33      #VALUE!
# 45  24.86666667
# Number of outliers in temperature: 37
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 380  C595      DEHRES19DEL01                 29.0                      4.6
# 425  C003      DEHRES13DEL02                 29.0                      4.6
# 490  C1EC      DEHRES04DEL03                 32.0                      4.8
# 564  C951      DEHRES08DEL03                 36.0                      4.8
# 659  D398      DEHRES08DEL01                 22.0                      4.6
#
#      Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 380            30.372202             78.077151                   30.442202
# 425           -30.366322            -78.070453                   30.496322
# 490            30.340722             78.060221                   30.430722
# 564            30.359722             78.067079                   30.499722
# 659            30.359722             78.067079                   30.469722
#
#      Delivery_location_longitude Type_of_order Type_of_vehicle  temperature  \
# 380                    78.147151         Meal      motorcycle          7.86
# 425                    78.200453        Snack         scooter         10.63
# 490                    78.150221       Buffet      motorcycle         10.83
# 564                    78.207079       Buffet      motorcycle          9.18
# 659                    78.177079        Snack      motorcycle          8.21
#
#      humidity  precipitation weather_description Traffic_Level  Distance (km)  \
# 380      77.0            0.0           clear sky     Very High          23.51
# 425      80.0            0.0           clear sky           NaN            NaN
# 490      77.0            0.0           clear sky     Very High          27.89
# 564      82.0            0.0           clear sky     Very High          59.67
# 659      80.0            0.0           clear sky     Very High          32.95
#
#           TARGET
# 380  73.88333333
# 425      #VALUE!
# 490        84.85
# 564       157.75
# 659  87.36666667
# Number of outliers in humidity: 0
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Type_of_order, Type_of_vehicle, temperature, humidity, precipitation, weather_description, Traffic_Level, Distance (km), TARGET]
# Index: []
# Number of outliers in precipitation: 543
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 52   C1FF     AURGRES20DEL03                 25.0                      5.0
# 67   98AA      VADRES16DEL02                 23.0                      4.8
# 73   1A70      MYSRES14DEL02                 29.0                      4.7
# 152  8D18   RANCHIRES12DEL02                 23.0                      4.8
# 153  9CBA      VADRES18DEL01                 36.0                      4.9
#
#      Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 52                   0.0                   0.0                        0.03
# 67                   0.0                   0.0                        0.02
# 73                   0.0                   0.0                        0.02
# 152                  0.0                   0.0                        0.02
# 153                  0.0                   0.0                        0.01
#
#      Delivery_location_longitude Type_of_order Type_of_vehicle  temperature  \
# 52                          0.03        Snack      motorcycle         26.28
# 67                          0.02         Meal         scooter         26.29
# 73                          0.02       Buffet      motorcycle         26.29
# 152                         0.02       Buffet         scooter         26.29
# 153                         0.01       Buffet         scooter         26.29
#
#      humidity  precipitation weather_description Traffic_Level  Distance (km)  \
# 52       85.0           0.10          light rain           NaN            NaN
# 67       85.0           0.11          light rain           NaN            NaN
# 73       85.0           0.11          light rain           NaN            NaN
# 152      85.0           0.11          light rain           NaN            NaN
# 153      85.0           0.12          light rain           NaN            NaN
#
#     TARGET
# 52     NaN
# 67     NaN
# 73     NaN
# 152    NaN
# 153    NaN
# Number of outliers in Distance (km): 72
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 102  3C57      MUMRES14DEL02                 23.0                      4.8
# 444  D800      DEHRES07DEL02                 37.0                      4.7
# 454  548E      HYDRES04DEL02                 33.0                      4.8
# 564  C951      DEHRES08DEL03                 36.0                      4.8
# 614  CEF2    LUDHRES010DEL03                 38.0                      4.1
#
#      Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 102            19.181300             72.836191                   19.311300
# 444            30.362686             78.068890                   30.492686
# 454            17.411028             78.329645                   17.541028
# 564            30.359722             78.067079                   30.499722
# 614            30.892860             75.822199                   31.032860
#
#      Delivery_location_longitude Type_of_order Type_of_vehicle  temperature  \
# 102                    72.966191         Meal      motorcycle         27.05
# 444                    78.198890       Buffet         scooter         12.01
# 454                    78.459645         Meal      motorcycle         21.20
# 564                    78.207079       Buffet      motorcycle          9.18
# 614                    75.962199        Snack         scooter         18.55
#
#      humidity  precipitation weather_description Traffic_Level  Distance (km)  \
# 102      49.0            0.0           clear sky     Very High          42.54
# 444      81.0            0.0           clear sky     Very High          54.27
# 454      67.0            0.0       broken clouds     Very High          53.49
# 564      82.0            0.0           clear sky     Very High          59.67
# 614      59.0            0.0           clear sky     Very High          43.62
#
#           TARGET
# 102  93.41666667
# 444  140.9833333
# 454  58.71666667
# 564       157.75
# 614  57.98333333

# %%
# plot the correlation matrix heatmap
# look into sns.heatmap() and annotate the values
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# plot pairplot for numerical columns
# look into sns.pairplot()
sns.pairplot(df[numeric_columns.columns])
plt.show()

# %%
# plot pairplot for categorical columns - these are treated differently than numerical

# Define categorical columns
categorical_columns = ['Type_of_order', 'Type_of_vehicle', 'weather_description', 'Traffic_Level']

# Plot count plots for each categorical column
plt.figure(figsize=(15, 10))

for i, column in enumerate(categorical_columns, 1):
    plt.subplot(2, 2, i)  # Adjust the number of rows and columns as needed
    sns.countplot(y=df[column])
    plt.title(column)

plt.tight_layout()
plt.show()

# %%
# Set up the figure and axes
plt.figure(figsize=(15, 10))

# Loop over numeric columns and create a boxplot for each
for i, column in enumerate(numeric_columns.columns, 1):
    plt.subplot(3, 4, i)  
    sns.boxplot(y=df[column])
    plt.title(column)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 1: Prepare the data for ML

# %%
# Drop unnecessary columns
df.drop(columns=['Unnamed: 14'], inplace=True)

# Drop rows where TARGET contains null values
df.dropna(subset=['TARGET'], inplace=True)

# Drop rows where TARGET contains '#VALUE!'
df = df[df['TARGET'] != '#VALUE!']

# Convert TARGET to float and round to 1 decimal place
df['TARGET'] = pd.to_numeric(df['TARGET'], errors='coerce')  # Convert to numeric, invalid values become NaN
df['TARGET'] = df['TARGET'].round(1)  # Round to 1 decimal place

# Remove any NaN values that might have been created during conversion
df.dropna(subset=['TARGET'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-fd643c431b3a> in <module>
#       1 # Drop unnecessary columns
# ----> 2 df.drop(columns=['Unnamed: 14'], inplace=True)
#       3
#       4 # Drop rows where TARGET contains null values
#       5 df.dropna(subset=['TARGET'], inplace=True)
#
# c:\Users\corbe\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# c:\Users\corbe\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# c:\Users\corbe\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# c:\Users\corbe\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['Unnamed: 14'] not found in axis"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           10000 non-null  object
#  1   Delivery_person_ID           10000 non-null  object
#  2   Delivery_person_Age          10000 non-null  float64
#  3   Delivery_person_Ratings      10000 non-null  float64
#  4   Restaurant_latitude          10000 non-null  float64
#  5   Restaurant_longitude         10000 non-null  float64
#  6   Delivery_location_latitude   10000 non-null  float64
#  7   Delivery_location_longitude  10000 non-null  float64
#  8   Type_of_order                10000 non-null  object
#  9   Type_of_vehicle              10000 non-null  object
#  10  temperature                  9995 non-null   float64
#  11  humidity                     9995 non-null   float64
#  12  precipitation                9995 non-null   float64
#  13  weather_description          9995 non-null   object
#  14  Traffic_Level                9085 non-null   object
#  15  Distance (km)                9080 non-null   float64
#  16  TARGET                       9459 non-null   object
# dtypes: float64(10), object(7)
# memory usage: 1.3+ MB

# %%
# Handle missing values in Distance
df['Distance (km)'] = df['Distance (km)'].fillna(df['Distance (km)'].mean())
df['Distance (km)'] = df['Distance (km)'].round(1)

# %%
# Drop ID columns as they don't contribute to prediction
df = df.drop(['ID', 'Delivery_person_ID'], axis=1)

# Clean and encode categorical variables
categorical_columns = ['Type_of_order', 'Type_of_vehicle', 'weather_description', 'Traffic_Level']
encoders = {}

# Fix categorical columns labels
for col in categorical_columns:
    df[col] = df[col].str.strip().str.title()  # Removes leading and trailing whitespace then capitalizes first letter of each word


# Then perform encoding
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    encoders[col] = le
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-2c23208fa5e6> in <module>
#       1 # Drop ID columns as they don't contribute to prediction
# ----> 2 df = df.drop(['ID', 'Delivery_person_ID'], axis=1)
#       3
#       4 # Clean and encode categorical variables
#       5 categorical_columns = ['Type_of_order', 'Type_of_vehicle', 'weather_description', 'Traffic_Level']
#
# c:\Users\corbe\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# c:\Users\corbe\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# c:\Users\corbe\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# c:\Users\corbe\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['ID' 'Delivery_person_ID'] not found in axis"

# %%
# For each categorical column, show the encoding mapping
for col, encoder in encoders.items():
    print(f"\nEncodings for {col}:")
    # Create a dictionary mapping classes to their encoded values
    mapping = dict(zip(encoder.classes_, encoder.transform(encoder.classes_)))
    for category, encoded_value in mapping.items():
        print(f"  {category}: {encoded_value}")

# %% [markdown]
# ### Step 2: Split features and target

# %%
X = df.drop('TARGET', axis=1)
y = df['TARGET']

# %% [markdown]
# This approach will ensure that you now have:
# - X_train, y_train (80% of the data) for training,
# - X_test, y_test (10% of the data) for test evaluation/validation,
# - X_final_test, y_final_test (10% of the data) for final testing (unseen data).

# %%
# Split data into training 80% and testing 20% sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

# Further split the 20% test set into two 10% sets (test evaluation/validation and final test)
X_test, X_final_test, y_test, y_final_test = train_test_split(X_test, y_test, test_size=0.5, random_state=13)

# %% [markdown]
# ### Step 3: Train the XGBoost model (manual)

# %%
# Convert data into DMatrix format
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-6980148d0b2b> in <module>
#       1 # Convert data into DMatrix format
# ----> 2 dtrain = xgb.DMatrix(X_train, label=y_train)
#       3 dtest = xgb.DMatrix(X_test, label=y_test)
#
# c:\Users\corbe\anaconda3\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     724             for k, arg in zip(sig.parameters, args):
#     725                 kwargs[k] = arg
# --> 726             return func(**kwargs)
#     727
#     728         return inner_f
#
# c:\Users\corbe\anaconda3\lib\site-packages\xgboost\core.py in __init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, data_split_mode)
#     876             return
#     877
# --> 878         handle, feature_names, feature_types = dispatch_data_backend(
#     879             data,
#     880             missing=self.missing,
#
# c:\Users\corbe\anaconda3\lib\site-packages\xgboost\data.py in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical, data_split_mode)
#    1205         data = pd.DataFrame(data)
#    1206     if _is_pandas_df(data):
# -> 1207         return _from_pandas_df(
#    1208             data,
#    1209             enable_categorical,
#
# c:\Users\corbe\anaconda3\lib\site-packages\xgboost\data.py in _from_pandas_df(data, enable_categorical, missing, nthread, feature_names, feature_types, data_split_mode)
#     638     data_split_mode: DataSplitMode = DataSplitMode.ROW,
#     639 ) -> DispatchedDataBackendReturnType:
# --> 640     df, feature_names, feature_types = _transform_pandas_df(
#     641         data, enable_categorical, feature_names, feature_types
#     642     )
#
# c:\Users\corbe\anaconda3\lib\site-packages\xgboost\data.py in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta)
#     601     meta: Optional[str] = None,
#     602 ) -> Tuple[PandasTransformed, Optional[FeatureNames], Optional[FeatureTypes]]:
# --> 603     pandas_check_dtypes(data, enable_categorical)
#     604     if meta and len(data.columns) > 1 and meta not in _matrix_meta:
#     605         raise ValueError(f"DataFrame for {meta} cannot have multiple columns")
#
# c:\Users\corbe\anaconda3\lib\site-packages\xgboost\data.py in pandas_check_dtypes(data, enable_categorical)
#     567             or is_pa_ext_dtype(dtype)
#     568         ):
# --> 569             _invalid_dataframe_dtype(data)
#     570
#     571         if is_pd_sparse_dtype(dtype):
#
# c:\Users\corbe\anaconda3\lib\site-packages\xgboost\data.py in _invalid_dataframe_dtype(data)
#     354     type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     355     msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 356     raise ValueError(msg)
#     357
#     358
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, the experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:Type_of_order: object, Type_of_vehicle: object, weather_description: object, Traffic_Level: object

# %%
# Set parameters
params = {
    "objective": "reg:squarederror",
    "learning_rate": 0.01,
    "max_depth": 4,
    "eval_metric": "rmse",
    "random_state": 13,
}

# %%
# Set evaluation list
evallist = [(dtrain, 'train'), (dtest, 'test')]

# Dictionary to store evaluation results
evals_result = {}

# Train model
num_round = 100

xgb_model = xgb.train(
    params,
    dtrain,
    num_round,
    evallist,
    evals_result=evals_result,
    verbose_eval=10
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-b3956538088b> in <module>
#       1 # Set evaluation list
# ----> 2 evallist = [(dtrain, 'train'), (dtest, 'test')]
#       3
#       4 # Dictionary to store evaluation results
#       5 evals_result = {}
#
# NameError: name 'dtrain' is not defined

# %% [markdown]
# ### Step 4: Evaluate the model (manual)

# %%
# Make predictions
dtest = xgb.DMatrix(X_test)

y_pred = xgb_model.predict(dtest)

# Calculate metrics
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("\nModel Evaluation Metrics:")
print(f"- RMSE: {rmse:.4f}")
print(f"- MAE: {mae:.4f}")
print(f"- R²: {r2:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-8d27e1ac51ed> in <module>
#       1 # Make predictions
# ----> 2 dtest = xgb.DMatrix(X_test)
#       3
#       4 y_pred = xgb_model.predict(dtest)
#       5
#
# c:\Users\corbe\anaconda3\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     724             for k, arg in zip(sig.parameters, args):
#     725                 kwargs[k] = arg
# --> 726             return func(**kwargs)
#     727
#     728         return inner_f
#
# c:\Users\corbe\anaconda3\lib\site-packages\xgboost\core.py in __init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, data_split_mode)
#     876             return
#     877
# --> 878         handle, feature_names, feature_types = dispatch_data_backend(
#     879             data,
#     880             missing=self.missing,
#
# c:\Users\corbe\anaconda3\lib\site-packages\xgboost\data.py in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical, data_split_mode)
#    1205         data = pd.DataFrame(data)
#    1206     if _is_pandas_df(data):
# -> 1207         return _from_pandas_df(
#    1208             data,
#    1209             enable_categorical,
#
# c:\Users\corbe\anaconda3\lib\site-packages\xgboost\data.py in _from_pandas_df(data, enable_categorical, missing, nthread, feature_names, feature_types, data_split_mode)
#     638     data_split_mode: DataSplitMode = DataSplitMode.ROW,
#     639 ) -> DispatchedDataBackendReturnType:
# --> 640     df, feature_names, feature_types = _transform_pandas_df(
#     641         data, enable_categorical, feature_names, feature_types
#     642     )
#
# c:\Users\corbe\anaconda3\lib\site-packages\xgboost\data.py in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta)
#     601     meta: Optional[str] = None,
#     602 ) -> Tuple[PandasTransformed, Optional[FeatureNames], Optional[FeatureTypes]]:
# --> 603     pandas_check_dtypes(data, enable_categorical)
#     604     if meta and len(data.columns) > 1 and meta not in _matrix_meta:
#     605         raise ValueError(f"DataFrame for {meta} cannot have multiple columns")
#
# c:\Users\corbe\anaconda3\lib\site-packages\xgboost\data.py in pandas_check_dtypes(data, enable_categorical)
#     567             or is_pa_ext_dtype(dtype)
#     568         ):
# --> 569             _invalid_dataframe_dtype(data)
#     570
#     571         if is_pd_sparse_dtype(dtype):
#
# c:\Users\corbe\anaconda3\lib\site-packages\xgboost\data.py in _invalid_dataframe_dtype(data)
#     354     type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     355     msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 356     raise ValueError(msg)
#     357
#     358
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, the experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:Type_of_order: object, Type_of_vehicle: object, weather_description: object, Traffic_Level: object

# %% [markdown]
# ### Step 5: Plot learning curves (manual)

# %% [markdown]
# Plot training test deviance for manual model

# %%
# Get the RMSE values for training and testing
train_rmse = evals_result['train']['rmse']
test_rmse = evals_result['test']['rmse']

# Create sequence of epochs
epochs = range(1, len(train_rmse) + 1)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_rmse, 'b-', label='Train')
plt.plot(epochs, test_rmse, 'r-', label='Test')

# Customize the plot
plt.title('XGBoost RMSE')
plt.xlabel('Boosting Iterations')
plt.ylabel('RMSE Distance')
plt.legend()
plt.grid(True, alpha=0.3)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Visualize tree for manual model

# %%
plt.rcParams['figure.figsize'] = (50, 25)
xgb.plot_tree(xgb_model, num_trees=0)
plt.show()

# %% [markdown]
# ### Step 6: Feature importance

# %% [markdown]
# Importance is calculated with either “gain”, “weight”, or “cover”
#
# - ”gain” is the average gain of splits which use the feature
# - ”weight” is the number of times a feature appears in a tree
# - ”cover” is the average coverage of splits which use the feature (where coverage is defined as the number of samples affected by the split)

# %%
# Gain
importance_scores = xgb_model.get_score(importance_type='gain')

# Sort features by importance score
sorted_features = sorted(importance_scores.items(), key=lambda x: x[1], reverse=True)

# Print feature importance
print("\nFeature Importance, Gain (High to Low):")
for feature, score in sorted_features:
    print(f"- {feature}: {score:.2f}")

# %%
plt.rcParams['figure.figsize'] = (10, 6)
xgb.plot_importance(xgb_model, importance_type='gain')
plt.show()

# %% [markdown]
# Cleaning up the above plot

# %%
# Get feature importance scores - Gain
importance_scores = xgb_model.get_score(importance_type='gain')

# Convert to list of tuples and sort by importance
importance_tuples = [(k, v) for k, v in importance_scores.items()]
importance_tuples.sort(key=lambda x: x[1])

# Separate features and scores
features = [tup[0] for tup in importance_tuples]
scores = [tup[1] for tup in importance_tuples]

# Create plot
plt.figure(figsize=(10, 6))
bars = plt.barh(range(len(scores)), scores)

# Add formatted labels
for rect in bars:
    width = rect.get_width()
    plt.text(width, rect.get_y() + rect.get_height()/2, 
             f'{width:.2f}', 
             ha='left', va='center',
             fontsize=10)

# Customize plot
plt.yticks(range(len(features)), features)
plt.xlabel('F Importance Score (gain)')
plt.title('Feature Importance')
plt.tight_layout()
plt.show()

# %%
# Weight
importance_scores = xgb_model.get_score(importance_type='weight')

# Sort features by importance score
sorted_features = sorted(importance_scores.items(), key=lambda x: x[1], reverse=True)

# Print feature importance
print("\nFeature Importance, Weight (High to Low):")
for feature, score in sorted_features:
    print(f"- {feature}: {score:.2f}")

# %%
# Get feature importance scores - Weight
importance_scores = xgb_model.get_score(importance_type='weight')

# Convert to list of tuples and sort by importance
importance_tuples = [(k, v) for k, v in importance_scores.items()]
importance_tuples.sort(key=lambda x: x[1])

# Separate features and scores
features = [tup[0] for tup in importance_tuples]
scores = [tup[1] for tup in importance_tuples]

# Create plot
plt.figure(figsize=(10, 6))
bars = plt.barh(range(len(scores)), scores)

# Add formatted labels
for rect in bars:
    width = rect.get_width()
    plt.text(width, rect.get_y() + rect.get_height()/2, 
             f'{width:.2f}', 
             ha='left', va='center',
             fontsize=10)

# Customize plot
plt.yticks(range(len(features)), features)
plt.xlabel('F Importance Score (weight)')
plt.title('Feature Importance')
plt.tight_layout()
plt.show()

# %%
# Cover
importance_scores = xgb_model.get_score(importance_type='cover')

# Sort features by importance score
sorted_features = sorted(importance_scores.items(), key=lambda x: x[1], reverse=True)

# Print feature importance
print("\nFeature Importance, Cover (High to Low):")
for feature, score in sorted_features:
    print(f"- {feature}: {score:.2f}")

# %%
# Get feature importance scores - Cover
importance_scores = xgb_model.get_score(importance_type='cover')

# Convert to list of tuples and sort by importance
importance_tuples = [(k, v) for k, v in importance_scores.items()]
importance_tuples.sort(key=lambda x: x[1])

# Separate features and scores
features = [tup[0] for tup in importance_tuples]
scores = [tup[1] for tup in importance_tuples]

# Create plot
plt.figure(figsize=(10, 6))
bars = plt.barh(range(len(scores)), scores)

# Add formatted labels
for rect in bars:
    width = rect.get_width()
    plt.text(width, rect.get_y() + rect.get_height()/2, 
             f'{width:.2f}', 
             ha='left', va='center',
             fontsize=10)

# Customize plot
plt.yticks(range(len(features)), features)
plt.xlabel('F Importance Score (cover)')
plt.title('Feature Importance')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 7: Cross validation and Hyperparameter tuning

# %%
def manual_cross_val_score(params, X, y, n_folds=5):
    """
    Perform manual cross-validation for XGBoost
    """
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=13)
    scores = []
    
    for train_idx, val_idx in kf.split(X):
        X_train_fold = X.iloc[train_idx]
        y_train_fold = y.iloc[train_idx]
        X_val_fold = X.iloc[val_idx]
        y_val_fold = y.iloc[val_idx]
        
        # Convert to DMatrix
        dtrain = xgb.DMatrix(X_train_fold, label=y_train_fold)
        dval = xgb.DMatrix(X_val_fold, label=y_val_fold)
        
        # Train model
        model = xgb.train(
            params,
            dtrain,
            num_boost_round=100,
            evals=[(dval, 'val')],
            verbose_eval=False
        )
        
        # Make predictions
        y_pred = model.predict(dval)
        rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred))
        scores.append(rmse)
    
    return np.mean(scores), np.std(scores)

def tune_xgboost_manual(X_train, y_train):
    """
    Manual parameter tuning for XGBoost
    """
    # Base parameters
    base_params = {
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse',
        'random_state': 13
    }
    
    # Parameter grid
    param_grid = {
        'max_depth': [3, 5, 7],
        'learning_rate': [0.01, 0.1, 0.3],
        'min_child_weight': [1, 3, 5],
        'subsample': [0.8, 0.9, 1.0],
    }
    
    # Store results
    results = []
    
    # Generate all parameter combinations
    param_combinations = [dict(zip(param_grid.keys(), v)) 
                        for v in product(*param_grid.values())]
    
    print(f"Testing {len(param_combinations)} parameter combinations...")
    
    for params in param_combinations:
        # Combine with base parameters
        current_params = {**base_params, **params}
        
        # Perform cross-validation
        mean_rmse, std_rmse = manual_cross_val_score(current_params, X_train, y_train)
        
        results.append({
            'params': params,
            'mean_rmse': mean_rmse,
            'std_rmse': std_rmse
        })
        
        print(f"Parameters: {params}")
        print(f"RMSE: {mean_rmse:.4f} (+/- {std_rmse:.4f})")
        print("-" * 50)
    
    # Convert results to DataFrame
    results_df = pd.DataFrame(results)
    
    # Find best parameters
    best_idx = results_df['mean_rmse'].argmin()
    best_params = results_df.iloc[best_idx]['params']
    
    print("\n***** Best parameters found: *****")
    print(best_params)
    print(f"***** Best RMSE: {results_df.iloc[best_idx]['mean_rmse']:.4f} *****")
    
    # Train final model with best parameters
    best_params = {**base_params, **best_params}
    dtrain = xgb.DMatrix(X_train, label=y_train)
    final_model = xgb.train(best_params, dtrain, num_boost_round=100)
    
    # Plot parameter effects
    plot_parameter_effects(results_df)

    # Before returning, create the complete parameter dictionary
    best_params_complete = {
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse',
        'random_state': 13,
        'max_depth': best_params['max_depth'],
        'learning_rate': best_params['learning_rate'],
        'min_child_weight': best_params['min_child_weight'],
        'subsample': best_params['subsample']
    }

    return final_model, results_df, best_params_complete

def plot_parameter_effects(results_df):
    """
    Plot the effects of different parameters on model performance
    """
    params = results_df['params'].iloc[0].keys()
    n_params = len(params)
    fig, axes = plt.subplots((n_params + 1) // 2, 2, figsize=(15, 5 * ((n_params + 1) // 2)))
    axes = axes.ravel()
    
    for idx, param in enumerate(params):
        # Extract values and scores for this parameter
        param_values = [p[param] for p in results_df['params']]
        
        # Calculate mean RMSE for each parameter value
        unique_values = sorted(set(param_values))
        mean_rmses = []
        
        for value in unique_values:
            mask = [p[param] == value for p in results_df['params']]
            mean_rmse = results_df.loc[mask, 'mean_rmse'].mean()
            mean_rmses.append(mean_rmse)
        
        # Plot
        axes[idx].plot(unique_values, mean_rmses, 'o-')
        axes[idx].set_xlabel(param)
        axes[idx].set_ylabel('Mean RMSE')
        axes[idx].set_title(f'Effect of {param}')
        axes[idx].grid(True)
    
    # Remove empty subplots
    for idx in range(n_params, len(axes)):
        fig.delaxes(axes[idx])
    
    plt.tight_layout()
    plt.show()

def evaluate_xgboost_model(model, X_train, X_test, y_train, y_test):
    """
    Evaluate XGBoost model performance
    """
    
    # Convert to DMatrix
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    
    # Make predictions
    y_train_pred = model.predict(dtrain)
    y_test_pred = model.predict(dtest)
    
    # Calculate metrics
    train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
    test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
    
    train_mae = mean_absolute_error(y_train, y_train_pred)
    test_mae = mean_absolute_error(y_test, y_test_pred)
    
    train_r2 = r2_score(y_train, y_train_pred)
    test_r2 = r2_score(y_test, y_test_pred)
    
    print("\nModel Performance Metrics:")
    print(f"- Training RMSE: {train_rmse:.4f}")
    print(f"- Testing RMSE: {test_rmse:.4f}")

    print(f"- Training MAE: {train_mae:.4f}")
    print(f"- Testing MAE: {test_mae:.4f}")
    
    print(f"- Training R²: {train_r2:.4f}")
    print(f"- Testing R²: {test_r2:.4f}")
    
    return train_rmse, test_rmse

# %% [markdown]
# ### Step 8: Run and tune the model

# %%
# Tune the model and get the best parameters
best_xgb_model, results_df, best_params_complete = tune_xgboost_manual(X_train, y_train)

# Evaluate the best model
train_rmse, test_rmse = evaluate_xgboost_model(
    best_xgb_model, X_train, X_test, y_train, y_test)

# %% [markdown]
# ### Step 9: Predict on unseen data (final test set) based on the **best XGBoost model**

# %%
# Convert final test data to DMatrix
dfinal = xgb.DMatrix(X_final_test)

# Make predictions on final test set
y_pred_final = best_xgb_model.predict(dfinal)

# Calculate metrics
rmse_final = np.sqrt(mean_squared_error(y_final_test, y_pred_final))
mae_final = mean_absolute_error(y_final_test, y_pred_final)
r2_final = r2_score(y_final_test, y_pred_final)

print("\nFinal Test Metrics:")
print(f"- RMSE: {rmse_final:.4f}")
print(f"- MAE: {mae_final:.4f}")
print(f"- R-squared: {r2_final:.4f}")

# %%
# Create comparison plot
plt.figure(figsize=(12, 6))

# Scatter plot
plt.subplot(1, 2, 1)
plt.scatter(y_final_test, y_pred_final, alpha=0.5)
plt.plot([y_final_test.min(), y_final_test.max()], 
            [y_final_test.min(), y_final_test.max()], 
            'r--', lw=2)
plt.xlabel('Actual Delivery Time')
plt.ylabel('Predicted Delivery Time')
plt.title('Actual vs Predicted Values')
plt.grid(True, alpha=0.3)

# Error distribution
plt.subplot(1, 2, 2)
errors = y_pred_final - y_final_test
plt.hist(errors, bins=30, edgecolor='black')
plt.xlabel('Prediction Error')
plt.ylabel('Count')
plt.title('Error Distribution')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Create detailed comparison DataFrame
comparison_df = pd.DataFrame({
    'Actual': y_final_test,
    'Predicted': y_pred_final,
    'Error': errors,
    'AbsoluteError': np.abs(errors)
})

comparison_df.head()

# %%
# Error Statistics of comparison_df
print("\nError Statistics:")
print(comparison_df['Error'].describe())

# %%
# Identify worst predictions
print("\nWorst 10 Predictions:")
worst_predictions = comparison_df.nlargest(10, 'AbsoluteError')
worst_predictions

# %%
# Identify best predictions
print("\nBest 10 Predictions:")
best_predictions = comparison_df.nsmallest(10, 'AbsoluteError')
best_predictions

# %% [markdown]
# ### Step 10: Save the model

# %%
import pickle

best_xgb_model.save_model('best_xgb_model_v3.json')  # Saves the model in JSON format
best_xgb_model.save_model('best_xgb_model_v3.bin')  # Saves the model in binary format

pickle.dump(best_xgb_model, open('best_xgb_model_v3.pkl', 'wb')) # Save the best model as a pickle binary file
pickle.dump(encoders, open('encoders_best_xgb_model_v3.pkl', 'wb')) # Save the encoders as a pickle binary file

# %% [markdown]
# ### Step 11: Predict on hand data

# %%
# First, create the data without the ID fields since we drop those
hand_prediction_data = {
    "Delivery_person_Age": 32.0,
    "Delivery_person_Ratings": 4.6,
    "Restaurant_latitude": 12.972793,
    "Restaurant_longitude": 80.249982,
    "Delivery_location_latitude": 13.012793,
    "Delivery_location_longitude": 80.289982,
    "Type_of_order": 'Snack',
    "Type_of_vehicle": 'Scooter',
    "temperature": 26.55,
    "humidity": 87.0,
    "precipitation": 0.0,
    "weather_description": 'Mist',
    "Traffic_Level": 'High',
    "Distance (km)": 9.89
}

# Convert to DataFrame
hand_prediction_df = pd.DataFrame([hand_prediction_data])

# Ensure correct data types for numeric columns
numeric_cols = ['Delivery_person_Age', 'Delivery_person_Ratings', 
                'Restaurant_latitude', 'Restaurant_longitude',
                'Delivery_location_latitude', 'Delivery_location_longitude',
                'temperature', 'humidity', 'precipitation', 'Distance (km)']

# Convert to numeric
for col in numeric_cols:
    hand_prediction_df[col] = pd.to_numeric(hand_prediction_df[col])

# Encode categorical variables using the same encoders from training
categorical_columns = ['Type_of_order', 'Type_of_vehicle', 'weather_description', 'Traffic_Level']

# Using the encoders dictionary from your training process
for col in categorical_columns:
    hand_prediction_df[col] = encoders[col].transform(hand_prediction_df[col])

# Convert to DMatrix
dpred_hand = xgb.DMatrix(hand_prediction_df)

# Make prediction
prediction = best_xgb_model.predict(dpred_hand)
print(f"Predicted delivery time: {prediction[0]:.2f} minutes")

# %% [markdown]
# ### Step 11: Plot learning curves (tuned/best models)

# %% [markdown]
# Plot training test deviance for tuned/best model

# %%
# Prepare data in DMatrix format
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# Set up evaluation list
eval_list = [(dtrain, 'train'), (dtest, 'test')]

# Dictionary to store evaluation results
evals_result = {}

# Get the best parameters with base parameters included
best_idx = results_df['mean_rmse'].argmin()
best_tuned_params = results_df.iloc[best_idx]['params']

# Create params_best using the tuned values
params_best = {
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse',
    'random_state': 13,
    'max_depth': best_tuned_params['max_depth'],
    'learning_rate': best_tuned_params['learning_rate'],
    'min_child_weight': best_tuned_params['min_child_weight'],
    'subsample': best_tuned_params['subsample']
}

print("\nBest parameters for model:")
for param, value in params_best.items():
    print(f"- {param}: {value}")

num_rounds = 100  # or whatever number of rounds your best model used

model = xgb.train(
    params_best,
    dtrain,
    num_rounds,
    evals=eval_list,
    evals_result=evals_result,
    verbose_eval=False
)

# Plot the training-test curve
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(evals_result['train']['rmse']) + 1), 
         evals_result['train']['rmse'], 
         'b-', 
         label='Train')
plt.plot(range(1, len(evals_result['test']['rmse']) + 1), 
         evals_result['test']['rmse'], 
         'r-', 
         label='Test')

# Customize the plot
plt.title('XGBoost Training-Test RMSE Curve')
plt.xlabel('Boosting Iterations')
plt.ylabel('RMSE')
plt.legend()
plt.grid(True, alpha=0.3)

# Add min values as text
min_train_rmse = min(evals_result['train']['rmse'])
min_test_rmse = min(evals_result['test']['rmse'])
plt.text(0.02, 0.98, f'Min Train RMSE: {min_train_rmse:.4f}\nMin Test RMSE: {min_test_rmse:.4f}',
         transform=plt.gca().transAxes, verticalalignment='top',
         bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.tight_layout()
plt.show()

# %% [markdown]
# Visualize tree for tuned/best model

# %%
plt.rcParams['figure.figsize'] = (50, 25)
xgb.plot_tree(best_xgb_model, num_trees=0)
plt.show()

# %% [markdown]
# ### References

# %% [markdown]
# - https://www.kaggle.com/datasets/gautamdeora7/food-delivery-time-a-multi-factor-dataset/data
# - https://colab.research.google.com/github/kirenz/regression/blob/main/docs/xgboost-regression.ipynb#scrollTo=U-tDjPhi7OBQ
# - https://randomrealizations.com/posts/xgboost-for-regression-in-python/
# - https://github.com/dmlc/xgboost/issues/6909
# - https://towardsdatascience.com/xgboost-intro-step-by-step-implementation-and-performance-comparison-6018dfa212f3
# - https://github.com/Genpeng/xgboost-examples/tree/master?tab=readme-ov-file
# - https://pygraphviz.github.io/documentation/stable/install.html
#     - `conda install python-graphviz`
